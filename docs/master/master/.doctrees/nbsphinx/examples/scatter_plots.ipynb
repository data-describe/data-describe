# %% [markdown]
# # Scatter Plots

# %%
import pandas as pd
import data_describe as dd

# %%
from sklearn.datasets import load_diabetes
data = load_diabetes()
df = pd.DataFrame(data.data, columns=list(data.feature_names))
df['target'] = data.target
df.shape
# Out:
# (442, 11)

# %%
df.head(2)
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
#
#          s4        s5        s6  target
# 0 -0.002592  0.019908 -0.017646   151.0
# 1 -0.039493 -0.068330 -0.092204    75.0

# %% [markdown]
# ## Scatterplot Matrix

# %%
dd.scatter_plots(df, plot_mode='matrix')

# %% [markdown]
# ## Show all plots

# %%
dd.scatter_plots(df, plot_mode='all')

# %% [markdown]
# ## Show plots of interest using scatterplot diagnostics

# %% [markdown]
# ## Filter plots by a diagnostic

# %%
dd.scatter_plots(df, plot_mode='diagnostic', threshold={'Outlier': 0.9})

# %%
dd.scatter_plots(df, plot_mode='diagnostic', threshold={'Striated': 0.9})
