# %% [markdown]
# # Topic Modeling

# %%
import pandas as pd

# %%
from data_describe.text.topic_modeling import topic_model
# Out:
# UserWarning: The Dask Engine for Modin is experimental.

# %%
from sklearn.datasets import fetch_20newsgroups
categories = ['alt.atheism']
newsgroups_train = fetch_20newsgroups(subset='train', categories=categories)

# %%
df = pd.DataFrame({"text": newsgroups_train['data']})

# %%
df.head()
# Out:
#                                                 text
# 0  From: darice@yoyo.cc.monash.edu.au (Fred Rice)...
# 1  From: chrisb@tafe.sa.edu.au (Chris BELL)\nSubj...
# 2  Subject: Re: The Inimitable Rushdie\nFrom: kma...
# 3  From: timmbake@mcl.ucsb.edu (Bake Timmons)\nSu...
# 4  From: I3150101@dbstu1.rz.tu-bs.de (Benedikt Ro...

# %% [markdown]
# ## Explicitly providing number of topics

# %%
lda_model = topic_model(df.text, num_topics=2)
lda_model
# Out:
#           Topic 1 Topic 1 Coefficient Value Topic 2 Topic 2 Coefficient Value
# Term 1          :                     0.014      |>                     0.024
# Term 2         >>                     0.011      >>                     0.005
# Term 3         |>                     0.007       |                     0.004
# Term 4        God                     0.007       -                     0.004
# Term 5          -                     0.005       A                     0.004
# Term 6   evidence                     0.004     had                     0.004
# Term 7      those                     0.004  system                     0.004
# Term 8       them                     0.004     God                     0.004
# Term 9        our                     0.003   moral                     0.004
# Term 10  atheists                     0.003     For                     0.004

# %% [markdown]
# ## Guess optimal number of topics and show elbow plot

# %%
lda_model = topic_model(df.text, num_topics=None)
lda_model
# Out:
# Fitting topic model: 100%|██████████| 9/9 [00:16<00:00,  1.81s/it, topic_num=10]
#         Topic 1 Topic 1 Coefficient Value   Topic 2 Topic 2 Coefficient Value  \
# Term 1       >>                     0.018   Islamic                     0.008
# Term 2        :                     0.016     Islam                     0.006
# Term 3       |>                     0.008         -                     0.005
# Term 4        |                     0.008        >I                     0.005
# Term 5      God                     0.007        >>                     0.005
# Term 6      had                     0.006       God                     0.005
# Term 7        -                     0.005    cannot                     0.004
# Term 8    those                     0.004  evidence                     0.004
# Term 9     time                     0.004    system                     0.004
# Term 10  things                     0.004     Jesus                     0.004
#
#                              Topic 3 Topic 3 Coefficient Value   Topic 4  \
# Term 1                            |>                     0.026        |>
# Term 2                             :                     0.010        >>
# Term 3                            >>                     0.005       God
# Term 4                      Livesey)                     0.005         :
# Term 5   livesey@solntze.wpd.sgi.com                     0.005         -
# Term 6                          (Jon                     0.005         A
# Term 7                      morality                     0.005       its
# Term 8                      atheists                     0.004       it.
# Term 9                         Allan                     0.004  atheists
# Term 10                   Schneider)                     0.004       god
#
#         Topic 4 Coefficient Value Topic 5 Topic 5 Coefficient Value   Topic 6  \
# Term 1                      0.022      |>                     0.022        >>
# Term 2                      0.012      >>                     0.009  evidence
# Term 3                      0.007       A                     0.005      good
# Term 4                      0.006     God                     0.005       God
# Term 5                      0.006    them                     0.005        am
# Term 6                      0.005   those                     0.005     moral
# Term 7                      0.005       +                     0.005       its
# Term 8                      0.005    free                     0.005   Islamic
# Term 9                      0.005   moral                     0.004       For
# Term 10                     0.004    over                     0.004     Islam
#
#         Topic 6 Coefficient Value    Topic 7 Topic 7 Coefficient Value  \
# Term 1                      0.008         |>                     0.009
# Term 2                      0.005         >>                     0.007
# Term 3                      0.005  religious                     0.006
# Term 4                      0.004   atheists                     0.005
# Term 5                      0.004        God                     0.005
# Term 6                      0.004       time                     0.004
# Term 7                      0.004      motto                     0.004
# Term 8                      0.004      Jesus                     0.004
# Term 9                      0.004   religion                     0.004
# Term 10                     0.004     things                     0.004
#
#           Topic 8 Topic 8 Coefficient Value   Topic 9  \
# Term 1          :                     0.031       God
# Term 2         |>                     0.008  atheists
# Term 3        God                     0.008       it.
# Term 4         >>                     0.006    strong
# Term 5   atheists                     0.005   atheism
# Term 6          -                     0.004        am
# Term 7        our                     0.004         -
# Term 8       them                     0.004   doesn't
# Term 9      There                     0.004     There
# Term 10         |                     0.004      them
#
#         Topic 9 Coefficient Value                     Topic 10  \
# Term 1                      0.006                           |>
# Term 2                      0.006                            -
# Term 3                      0.005                        moral
# Term 4                      0.005                     morality
# Term 5                      0.004                         (Jon
# Term 6                      0.004                     Livesey)
# Term 7                      0.004                    objective
# Term 8                      0.004  livesey@solntze.wpd.sgi.com
# Term 9                      0.004                        these
# Term 10                     0.004                         What
#
#         Topic 10 Coefficient Value
# Term 1                       0.043
# Term 2                       0.009
# Term 3                       0.008
# Term 4                       0.006
# Term 5                       0.006
# Term 6                       0.006
# Term 7                       0.005
# Term 8                       0.005
# Term 9                       0.005
# Term 10                      0.004

# %%
lda_model.elbow_plot()
# Out:
# <AxesSubplot:title={'center':'Coherence Values Across Topic Numbers'}, xlabel='Number of Topics', ylabel='Coherence Values'>
