# %% [markdown]
# # Data Summary

# %%
import pandas as pd
from mwdata import data_summary

# %%
df=pd.read_csv("../data/NFL Play by Play 2009-2016 (v3).csv", low_memory=False)

# %%
df.Date = pd.to_datetime(df.Date)
df.PlayAttempted = df.PlayAttempted.astype(bool)

# %%
# %%time
data_summary(df)
# Out:
# CPU times: user 18.1 s, sys: 1.27 s, total: 19.4 s
# Wall time: 12.3 s
#                                       Date       GameID    Drive      qtr  \
# Data Type                   datetime64[ns]        int64    int64    int64
# Mean                                        2.01266e+09  12.3471  2.57823
# Standard Deviation                          2.29226e+06  7.16817  1.13026
# Median                                      2.01309e+09       12        3
# Min                    2009-09-10 00:00:00   2009091000        1        1
# Max                    2017-01-01 00:00:00   2017010115       35        5
# # Zeros                                               0        0        0
# # Nulls                                  0            0        0        0
# % Most Frequent Value                 0.79         0.08     4.71    27.64
#
#                           down    time TimeUnder TimeSecs PlayTimeDiff  \
# Data Type              float64  object     int64  float64      float64
# Mean                   2.00123           7.38608  1695.23      20.5746
# Standard Deviation       1.006           4.64213  1063.07      18.0305
# Median                       2                 7     1800           17
# Min                          1                 0     -900            0
# Max                          4                15     3600          943
# # Zeros                      0              6006     2027        47470
# # Nulls                  54218     188         0      188          374
# % Most Frequent Value    34.12    2.89        10     1.14         13.1
#
#                       SideofField  ...    yacEPA Home_WP_pre Away_WP_pre  \
# Data Type                  object  ...   float64     float64     float64
# Mean                               ... -0.386522    0.533889    0.466561
# Standard Deviation                 ...   1.97296    0.286415    0.286468
# Median                             ...         0    0.531286     0.46904
# Min                                ...       -14           0           0
# Max                                ...   9.55983           1           1
# # Zeros                            ...     20703         731         976
# # Nulls                       450  ...    220734       21943       21943
# % Most Frequent Value        3.28  ...      5.71        0.36        0.36
#
#                       Home_WP_post Away_WP_post  Win_Prob         WPA  \
# Data Type                  float64      float64   float64     float64
# Mean                      0.534217     0.466185  0.501311  0.00216328
# Standard Deviation        0.288647     0.288694  0.288207   0.0453262
# Median                    0.533689     0.466617  0.504349           0
# Min                              0            0         0   -0.997214
# Max                              1            1         1    0.994848
# # Zeros                       1460         1948       168       29300
# # Nulls                      23360        23360     21993        4817
# % Most Frequent Value         0.58         0.54       0.7        8.08
#
#                            airWPA     yacWPA   Season
# Data Type                 float64    float64    int64
# Mean                    0.0152089 -0.0104918  2012.52
# Standard Deviation      0.0564215  0.0679719  2.29008
# Median                 0.00355663          0     2013
# Min                     -0.999881  -0.986673     2009
# Max                      0.994848          1     2016
# # Zeros                        13      20755        0
# # Nulls                    220738     220956        0
# % Most Frequent Value        0.01       5.73    12.73
#
# [9 rows x 102 columns]
