# %% [markdown]
# # Feature Importance

# %%
import pandas as pd
import sys
sys.path.append('..')
import mwdata as mw

from sklearn.naive_bayes import GaussianNB

# %%
import warnings
warnings.simplefilter("ignore")

# %%
df = pd.read_csv('../data/er_data.csv')
df.drop('number_inpatient',axis=1, inplace=True)
df.head(1)
# Out:
#    readmitted  gender      age weight admission_type_id  \
# 0       False  Female  [50-60)      ?          Elective
#
#   discharge_disposition_id admission_source_id  time_in_hospital payer_code  \
# 0       Discharged to home  Physician Referral                 1         CP
#
#   medical_specialty  ...  glipizide.metformin  glimepiride.pioglitazone  \
# 0     Surgery-Neuro  ...                   No                        No
#
#    metformin.rosiglitazone  metformin.pioglitazone  change diabetesMed  \
# 0                       No                      No      No          No
#
#   Unnamed: 47                         diag_1_desc  \
# 0         NaN  Spinal stenosis in cervical region
#
#                           diag_2_desc                          diag_3_desc
# 0  Spinal stenosis in cervical region  Effusion of joint, site unspecified
#
# [1 rows x 50 columns]

# %% [markdown]
# ## Default
# Pass in the data frame and the column name of the response variable

# %%
mw.importance(df, 'readmitted')
# Out:
# Text(0.5, 1.0, 'Feature Importance')

# %% [markdown]
# ## Show negative importance
# Use `truncate=False` to disable removal of negative importance values.

# %%
mw.importance(df, 'readmitted', truncate=False)
# Out:
# Text(0.5, 1.0, 'Feature Importance')

# %% [markdown]
# ## Getting the data values
# You can get the importance values by setting `return_values` to `True`.

# %%
mw.importance(df, 'readmitted', return_values=True)
# Out:
# array([0.00e+00, 3.18e-03, 0.00e+00, 3.06e-03, 9.90e-03, 1.68e-03,
#        4.42e-03, 0.00e+00, 0.00e+00, 4.12e-03, 5.98e-03, 5.38e-03,
#        0.00e+00, 0.00e+00, 6.72e-03, 2.52e-03, 2.80e-04, 0.00e+00,
#        0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 6.00e-05, 0.00e+00,
#        0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 2.80e-04,
#        5.60e-04, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00,
#        0.00e+00, 0.00e+00, 1.00e-04, 0.00e+00, 0.00e+00, 0.00e+00,
#        0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 2.02e-03])

# %% [markdown]
# ## Alternate Model
# You can also specify a different model type using the `estimator` argument.

# %%
mw.importance(df, 'readmitted', estimator=GaussianNB())
# Out:
# Text(0.5, 1.0, 'Feature Importance')
