# %% [markdown]
# # Geospatial

# %%
import data_describe as mw
from data_describe.geospatial.mapping import maps
import geopandas as gpd

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.head()
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                             geometry
# 0  (POLYGON ((180 -16.06713266364245, 180 -16.555...
# 1  POLYGON ((33.90371119710453 -0.950000000000000...
# 2  POLYGON ((-8.665589565454809 27.65642588959236...
# 3  (POLYGON ((-122.84 49.00000000000011, -122.974...
# 4  (POLYGON ((-122.84 49.00000000000011, -120 49....

# %% [markdown]
# ## Default choropleth map with color selected

# %%
maps(world, feature="pop_est")

# %% [markdown]
# ## Default choropleth map without selecting color

# %%
maps(world, feature="pop_est")

# %% [markdown]
# ## KDE map

# %%
maps(data=world, feature='pop_est', map_type="kde")
# Out:
# /Users/richardtruong-chau/miniconda3/envs/dd_env/lib/python3.7/site-packages/data_describe/geospatial/mapping.py:49: UserWarning:
#
# Large number of rows, processing will take awhile
