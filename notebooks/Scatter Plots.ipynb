# %% [markdown]
# # Scatter Plots

# %%
import pandas as pd
import sys
sys.path.append('..')
import mwdata as mw
import matplotlib.style as style

# %%
df = pd.read_csv("../data/er_data.csv")

# %%
df.head(2)
# Out:
#    readmitted  gender      age   weight admission_type_id  \
# 0       False  Female  [50-60)        ?          Elective
# 1       False  Female  [20-30)  [50-75)            Urgent
#
#   discharge_disposition_id admission_source_id  time_in_hospital payer_code  \
# 0       Discharged to home  Physician Referral                 1         CP
# 1       Discharged to home  Physician Referral                 2         UN
#
#   medical_specialty  ...  glipizide.metformin  glimepiride.pioglitazone  \
# 0     Surgery-Neuro  ...                   No                        No
# 1                 ?  ...                   No                        No
#
#    metformin.rosiglitazone  metformin.pioglitazone  change  diabetesMed  \
# 0                       No                      No      No           No
# 1                       No                      No      No           No
#
#   Unnamed: 47                                        diag_1_desc  \
# 0         NaN                 Spinal stenosis in cervical region
# 1         NaN  First-degree perineal laceration, unspecified ...
#
#                                          diag_2_desc  \
# 0                 Spinal stenosis in cervical region
# 1  Diabetes mellitus of mother, complicating preg...
#
#                            diag_3_desc
# 0  Effusion of joint, site unspecified
# 1                 Sideroblastic anemia
#
# [2 rows x 51 columns]

# %%
df = df.dropna(axis=1, how='all')

# %% [markdown]
# ## Scatterplot Matrix

# %%
mw.scatter_plots(df, plot_mode='matrix')

# %% [markdown]
# ## Show all plots

# %%
mw.scatter_plots(df, plot_mode='all')
# Out:
# [<seaborn.axisgrid.JointGrid at 0x12175d4e0>,
#  <seaborn.axisgrid.JointGrid at 0x1225ba828>,
#  <seaborn.axisgrid.JointGrid at 0x122bedd68>,
#  <seaborn.axisgrid.JointGrid at 0x122fa6e48>,
#  <seaborn.axisgrid.JointGrid at 0x123a2f358>,
#  <seaborn.axisgrid.JointGrid at 0x1240f7710>,
#  <seaborn.axisgrid.JointGrid at 0x124852710>,
#  <seaborn.axisgrid.JointGrid at 0x124e57278>,
#  <seaborn.axisgrid.JointGrid at 0x1254c0080>,
#  <seaborn.axisgrid.JointGrid at 0x123d9d160>,
#  <seaborn.axisgrid.JointGrid at 0x12634fda0>,
#  <seaborn.axisgrid.JointGrid at 0x126a3e390>,
#  <seaborn.axisgrid.JointGrid at 0x127092cc0>,
#  <seaborn.axisgrid.JointGrid at 0x127826da0>,
#  <seaborn.axisgrid.JointGrid at 0x127becbe0>,
#  <seaborn.axisgrid.JointGrid at 0x1285fff28>,
#  <seaborn.axisgrid.JointGrid at 0x128d3eac8>,
#  <seaborn.axisgrid.JointGrid at 0x128636780>,
#  <seaborn.axisgrid.JointGrid at 0x129757a58>,
#  <seaborn.axisgrid.JointGrid at 0x12a0c19e8>,
#  <seaborn.axisgrid.JointGrid at 0x12a90f9e8>,
#  <seaborn.axisgrid.JointGrid at 0x12afd3080>,
#  <seaborn.axisgrid.JointGrid at 0x12b5ddb38>,
#  <seaborn.axisgrid.JointGrid at 0x12bdde438>,
#  <seaborn.axisgrid.JointGrid at 0x12c4ded30>,
#  <seaborn.axisgrid.JointGrid at 0x12cb957f0>,
#  <seaborn.axisgrid.JointGrid at 0x12d2e54e0>,
#  <seaborn.axisgrid.JointGrid at 0x12d933438>]

# %% [markdown]
# ## Show plots of interest using scatterplot diagnostics

# %%
mw.scatter_plots(df)
# Out:
# [<seaborn.axisgrid.JointGrid at 0x12e0e45c0>,
#  <seaborn.axisgrid.JointGrid at 0x12e47aa20>,
#  <seaborn.axisgrid.JointGrid at 0x12efa29b0>,
#  <seaborn.axisgrid.JointGrid at 0x12f6a7320>,
#  <seaborn.axisgrid.JointGrid at 0x12fd8f8d0>,
#  <seaborn.axisgrid.JointGrid at 0x12fdc7d30>,
#  <seaborn.axisgrid.JointGrid at 0x130b98710>,
#  <seaborn.axisgrid.JointGrid at 0x1311ea0f0>,
#  <seaborn.axisgrid.JointGrid at 0x131548dd8>,
#  <seaborn.axisgrid.JointGrid at 0x131fc5e10>,
#  <seaborn.axisgrid.JointGrid at 0x132664400>,
#  <seaborn.axisgrid.JointGrid at 0x132d6ed30>,
#  <seaborn.axisgrid.JointGrid at 0x1333fe5f8>,
#  <seaborn.axisgrid.JointGrid at 0x131c2fef0>,
#  <seaborn.axisgrid.JointGrid at 0x134208780>,
#  <seaborn.axisgrid.JointGrid at 0x134971978>,
#  <seaborn.axisgrid.JointGrid at 0x1349364e0>,
#  <seaborn.axisgrid.JointGrid at 0x1356c6a58>,
#  <seaborn.axisgrid.JointGrid at 0x1357124e0>,
#  <seaborn.axisgrid.JointGrid at 0x13648f940>,
#  <seaborn.axisgrid.JointGrid at 0x136bdd048>,
#  <seaborn.axisgrid.JointGrid at 0x1372c6438>,
#  <seaborn.axisgrid.JointGrid at 0x1378c0ac8>,
#  <seaborn.axisgrid.JointGrid at 0x138073320>,
#  <seaborn.axisgrid.JointGrid at 0x138674978>,
#  <seaborn.axisgrid.JointGrid at 0x138e5f7f0>,
#  <seaborn.axisgrid.JointGrid at 0x13958b6d8>,
#  <seaborn.axisgrid.JointGrid at 0x139c1c470>]

# %% [markdown]
# ## Filter plots by a diagnostic

# %%
mw.scatter_plots(df, threshold={'Outlier': 0.9})
# Out:
# [<seaborn.axisgrid.JointGrid at 0x1395e3ef0>,
#  <seaborn.axisgrid.JointGrid at 0x13ac12c50>]

# %%
mw.scatter_plots(df, threshold={'Striated': 0.9})
# Out:
# [<seaborn.axisgrid.JointGrid at 0x13b171f28>,
#  <seaborn.axisgrid.JointGrid at 0x13b941208>,
#  <seaborn.axisgrid.JointGrid at 0x13c022588>,
#  <seaborn.axisgrid.JointGrid at 0x13c6a79e8>,
#  <seaborn.axisgrid.JointGrid at 0x13cd95d30>,
#  <seaborn.axisgrid.JointGrid at 0x13d4ff748>,
#  <seaborn.axisgrid.JointGrid at 0x13dbe26d8>,
#  <seaborn.axisgrid.JointGrid at 0x13a671320>,
#  <seaborn.axisgrid.JointGrid at 0x13e852748>,
#  <seaborn.axisgrid.JointGrid at 0x13a6716d8>,
#  <seaborn.axisgrid.JointGrid at 0x13f5ea2e8>,
#  <seaborn.axisgrid.JointGrid at 0x13f9add68>,
#  <seaborn.axisgrid.JointGrid at 0x14007b2b0>]
